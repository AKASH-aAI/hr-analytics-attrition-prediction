# %% [markdown]
# # Load data

# %%
import pandas as pd 

df = pd.read_csv('../data/HR.csv')

# %%
df.rename(columns={'left':'employee_left'}, inplace=True)

# %%
df['employee_left'].value_counts()
# Out:
# employee_left
# 0    11428
# 1     3574
# Name: count, dtype: int64

# %% [markdown]
# ## To SQL

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:akash99110@localhost/hranalysis"
)

df.to_sql(
    name='hr_employee',
    con=engine,
    if_exists='append',
    index=False
)

print('data sended succesfully')
# Out:
# data sended succesfully

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'time_spend_company', 'Work_accident',
#        'employee_left', 'promotion_last_5years', 'department', 'salary'],
#       dtype='str')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    time_spend_company  Work_accident  employee_left  promotion_last_5years  \
# 0                   3              0              1                      0
# 1                   6              0              1                      0
# 2                   4              0              1                      0
# 3                   5              0              1                      0
# 4                   3              0              1                      0
#
#   department  salary
# 0      sales     low
# ...
